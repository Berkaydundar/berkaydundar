# %%
number = float(input("Choose 1 or 2 or 3 "))


if number==1:

    print("To find hypotenus")

    a = ("first edge of traingle")

    b = ("second edge of traingle")

    c = ("hypotenuse of traingle")

    a = float(input("Enter the a "))

    b = float(input("Enter the b "))

    c = (a**2 + b**2)**0.5

    print('hypotenuse of triangle:' ,  c )  
    

if number==2:

    print("To count up from to the number you choose")

    i = 1

    x = float(int(input("Enter your number:")))

    while i - 1 < x:

        print(i)

        i += 1   

if number==3:

    print("To find arithmetic avarege")

    number1 = float(input("Enter the first number :" ))

    number2 = float(input("Enter the second number:" ))

    number3 = float(input("Enter the third number :" ))

    number4 = float(input("Enter the fourth number:" ))

    number5 = float(input("Enter the fifth number :" ))

    number6 = float(input("Enter the sixth number :" ))

    print("arithmetic average:" , (number1 + number2 + number3 + number4 + number5 + number6)/6)

    
if number < 1:
    print("   You chose wrong number, Please restart program and choose 1 or 2 or 3  ")
    
if number > 3:
    print("   You chose wrong number, Please restart program and choose 1 or 2 or 3  ")
    
if number < 3 and number > 2:
    print("   You chose wrong number, Please restart program and choose 1 or 2 or 3   ")
    
if number < 2 and number > 1:
    print("   You chose wrong number, Please restart program and choose 1 or 2 or 3   ")
